# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
# Enable LaTeX for all text
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],
    "mathtext.fontset": "cm",
})

# %%
names_and_paths = [
    ("KL-Cov", "/ptmp/rfechner/out/exp17_rollouts/qwen2.5_7b__kl-cov/val_jsonl/30_rollouts.jsonl"),
    ("GRPO", "/ptmp/rfechner/out/exp05_rollouts_qwen2.5-7b/qwen2.5_7b__grpo/val_jsonl/30_rollouts.jsonl"),
    ('KL-Cov + Pass@k Training', '/ptmp/rfechner/out/exp17_rollouts/qwen2.5_7b__klcov_passk/val_jsonl/30_rollouts.jsonl'),
    ('Pass@k Training', '/ptmp/rfechner/out/exp05_rollouts_qwen2.5-7b/qwen2.5_7b__grpo-passk/val_jsonl/30_rollouts.jsonl')
]

# %%
from workspace.plots.util import calculate_pass_at_k, qwen25_7b_lowvar_baselinepassk

# %%
recompute=False
basepassk = qwen25_7b_lowvar_baselinepassk(recompute=recompute)

# %%
dfs = {}
for name, file in names_and_paths:
    with open(file, 'r') as f:
        dfs[name] = pd.read_json(f, lines=True)

# %%
passk = {}
for mm, df in dfs.items():
    passk[mm] = calculate_pass_at_k(df)

# %%
passk['Base'] = basepassk

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset

names = list(passk.keys())
colors  = {
    'KL-Cov': 'green',
    'Pass@k Training': 'blue',
    'KL-Cov + Pass@k Training': 'red',
    'GRPO' : 'orange',
    'Base' : 'black'
}
dataset_names = sorted(list(passk['KL-Cov'].keys()))
fig, axes = plt.subplots(nrows=1, ncols=len(dataset_names), figsize=(3*len(dataset_names), 3.5))

# Sicherstellen, dass axes immer iterierbar ist (falls nur 1 Dataset existiert)
if len(dataset_names) == 1:
    axes = [axes]

for i, (ax, name) in enumerate(zip(axes, dataset_names)):
    for k, v in passk.items():
        vs = v[name].mean(axis=0)
        ax.plot(vs, label=k, color=colors[k])
    
    ax.set_title(name)
    ax.set_xticks(np.arange(len(vs)))
    ax.set_xticklabels(2**np.arange(len(vs)))
    ax.set_xlabel('k')
    ax.grid()
    # Zoom-In Effekt für den LETZTEN Plot
    if i == len(dataset_names) - 1:
        # Inset erstellen
        ax_ins = inset_axes(ax, width="35%", height="35%", loc='lower right', borderpad=2)
        
        for k, v in passk.items():
            vs = v[name].mean(axis=0)
            ax_ins.plot(vs, color=colors[k])
        
        ax_ins.set_xlim(7, 8)
        ax_ins.set_ylim(0.94, 0.98)
        ax_ins.set_xticks([7, 8], [128, 256])

        # ALLE VIER VERBINDUNGSLINIEN ZEICHNEN:
        # loc1 und loc2 definieren, welche Ecken verbunden werden.
        # Wir rufen es zweimal auf, um alle vier Ecken abzudecken:
        mark_inset(ax, ax_ins, loc1=1, loc2=4, fc="none", ec="0.5", ls="--", lw=0.7)
        mark_inset(ax, ax_ins, loc1=2, loc2=3, fc="none", ec="0.5", ls="--", lw=0.7)

axes[0].set_ylabel('Pass@k')
plt.suptitle('Pass@k for different Datasets', fontsize=15)

# Legende fixieren
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', ncol=5, bbox_to_anchor=(0.5, 0.05))
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_41850/48097133.py:55: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
